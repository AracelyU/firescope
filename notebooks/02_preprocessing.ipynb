# %% [markdown]
# Paso 1: Importaciones y configuración

# %%
import os
import glob
import rasterio
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from rasterio.plot import show
import fiona, time
from rasterio.plot import plotting_extent
from rasterio.warp import reproject, Resampling
from rasterio.enums import Resampling

# Configuración de rutas relativas (asumiendo que el notebook está en /notebooks)
RAW_DIR = "../data/raw"
PREPROCESING_DIR = "../data/processed"
RASTER_DIR = "../outputs/figures/raster/processed"
os.makedirs(RASTER_DIR, exist_ok=True)

print("✅ Librerías importadas y rutas configuradas.")
# Out:
# ✅ Librerías importadas y rutas configuradas.

# %%
def classify_ndvi_dynamic(ndvi, quantiles=[0.25, 0.50, 0.75]):
    """
    Clasifica NDVI dinámicamente usando cuantiles.
    Retorna un array con clases 1–4.

    Classes:
    1 = NDVI muy bajo
    2 = NDVI bajo
    3 = NDVI medio
    4 = NDVI alto
    """

    flat = ndvi[np.isfinite(ndvi)].ravel()

    q1, q2, q3 = np.quantile(flat, quantiles)

    print("\n=== UMBRALES DINÁMICOS NDVI ===")
    print(f" q1 (25%):  {q1:.3f}")
    print(f" q2 (50%):  {q2:.3f}")
    print(f" q3 (75%):  {q3:.3f}")

    ndvi_class = np.zeros_like(ndvi, dtype=np.uint8)

    ndvi_class[ndvi < q1] = 1
    ndvi_class[(ndvi >= q1) & (ndvi < q2)] = 2
    ndvi_class[(ndvi >= q2) & (ndvi < q3)] = 3
    ndvi_class[ndvi >= q3] = 4

    return ndvi_class, (q1, q2, q3)

# Diccionario con tus archivos raster clave
rasters = {
    "Viento (ERA5)": os.path.join(RAW_DIR, "era5_wind_valdivia.tif"),
    "Vegetación (Sentinel-2)": os.path.join(RAW_DIR, "sentinel2_valdivia.tif"),
    "Topología (SRTM)": os.path.join(RAW_DIR, "srtm_valdivia.tif")
}

def ensure_dir(path):
    os.makedirs(path, exist_ok=True)

ensure_dir(PREPROCESING_DIR)

def save_raster(path, array, profile):
    profile_out = profile.copy()
    profile_out.update(count=array.shape[0])
    with rasterio.open(path, 'w', **profile_out) as dst:
        dst.write(array)

# ---------------------------------------------------
# --------- FUNCIÓN PARA NORMALIZAR REFLECTANCIA ----
# ---------------------------------------------------

def normalize_if_needed(band):
    """Detecta si una banda está normalizada y la normaliza a rango [0,1] si es necesario."""

    bmin, bmax = np.nanmin(band), np.nanmax(band)
    print(f"   → Banda min={bmin:.3f}, max={bmax:.3f}")

    # Caso A: los valores ya están entre 0 y 1
    if 0 <= bmin >= -0.01 and 0 <= bmax <= 1.5:
        print("   ✓ Banda YA está normalizada.")
        return band

    # Caso B: Sentinel-2 típico (0–10000)
    if bmax > 1 and bmax <= 20000:
        print("   ✓ Normalizando banda (escala 0–10000 → 0–1).")
        return band / 10000.0

    # Caso C: TIFF uint16 completo (0–65535)
    if bmax > 20000:
        print("   ✓ Normalizando banda (escala 0–65535 → 0–1).")
        return band / 65535.0

    print("   ⚠ Banda no reconocida, intentando normalizar por máximo detectado.")
    return band / bmax


# ---------------------------------------------------
# --------------------- PROCESAMIENTO ----------------
# ---------------------------------------------------

for nombre, ruta in rasters.items():

    print(f"\nProcesando: {nombre}")

    if not os.path.exists(ruta):
        print(f"❌ No encontrado: {ruta}")
        continue
    
    with rasterio.open(ruta) as src:
        data = src.read().astype(float)
        profile = src.profile

    # ============================================================
    # ----------------------  VEGETACIÓN S2 -----------------------
    # ============================================================
    if "Vegetación" in nombre:
    
        print("\n--- Normalización Sentinel-2 ---")
    
        # Sentinel-2: bandas uint16 → normalizar a [0,1]
        red   = normalize_if_needed(data[0])
        green = normalize_if_needed(data[1])
        blue  = normalize_if_needed(data[2])
        nir   = normalize_if_needed(data[3])
    
        # NDVI
        ndvi = (nir - red) / (nir + red + 1e-6)
    
        # ===============================
        #  CLASIFICACIÓN NDVI DINÁMICA
        # ===============================
        ndvi_clean = ndvi[np.isfinite(ndvi)]  # quitar Nan/Inf
    
        # Evitar errores si todos los valores son iguales
        if len(np.unique(ndvi_clean)) == 1:
            print("⚠ NDVI constante: se asigna todo a clase 1.")
            ndvi_class = np.ones_like(ndvi, dtype=np.uint8)
        else:
            # Cuantiles
            q1, q2, q3 = np.quantile(ndvi_clean, [0.25, 0.50, 0.75])
    
            print(f"Cuantiles NDVI dinámicos:")
            print(f" Q1 = {q1:.3f}, Q2 = {q2:.3f}, Q3 = {q3:.3f}")
    
            ndvi_class = np.zeros_like(ndvi, dtype=np.uint8)
            ndvi_class[ndvi < q1] = 1
            ndvi_class[(ndvi >= q1) & (ndvi < q2)] = 2
            ndvi_class[(ndvi >= q2) & (ndvi < q3)] = 3
            ndvi_class[ndvi >= q3] = 4
    
        # Stack final
        processed = np.stack([red, green, blue, nir, ndvi, ndvi_class])
    
        profile_out = profile.copy()
        profile_out.update(dtype=rasterio.float32, count=processed.shape[0])
    
        save_raster(os.path.join(PREPROCESING_DIR, "vegetacion_processed.tif"),
                    processed.astype(np.float32), profile_out)
    
        print("✓ Vegetación procesada.")


    # ============================================================
    # -----------------------  VIENTO ERA5 ------------------------
    # ============================================================
    elif "Viento" in nombre:

        u, v = data
        mag = np.sqrt(u**2 + v**2)
        direc = (np.arctan2(v, u) * 180 / np.pi + 360) % 360

        processed = np.stack([u, v, mag, direc])

        profile_out = profile.copy()
        profile_out.update(dtype=rasterio.float32, count=processed.shape[0])

        save_raster(os.path.join(PREPROCESING_DIR, "viento_processed.tif"),
                    processed.astype(np.float32), profile_out)

        print("✓ Viento procesado.")

    # ============================================================
    # -----------------------  TOPOGRAFÍA SRTM --------------------
    # ============================================================
    elif "Topología" in nombre:

        elev = data[0]

        dy, dx = np.gradient(elev.astype(float), 
                             profile["transform"][4], 
                             profile["transform"][0])

        # Pendiente en grados (0–90°)
        slope = np.arctan(np.sqrt(dx**2 + dy**2)) * 180 / np.pi

        # Aspecto (orientación de la pendiente)
        aspect = np.arctan2(dx, -dy) * 180 / np.pi
        aspect = (aspect + 360) % 360

        processed = np.stack([elev, slope, aspect])

        profile_out = profile.copy()
        profile_out.update(dtype=rasterio.float32, count=processed.shape[0])

        save_raster(os.path.join(PREPROCESING_DIR, "topologia_processed.tif"),
                    processed.astype(np.float32), profile_out)

        print("✓ Topografía procesada.")

print("\n=== PREPROCESAMIENTO COMPLETO ===")
print("Datos guardados en:", PREPROCESING_DIR)
# Out:
# Procesando: Viento (ERA5)
# ✓ Viento procesado.
#
# Procesando: Vegetación (Sentinel-2)
#
# --- Normalización Sentinel-2 ---
#    → Banda min=0.000, max=8600.000
#    ✓ Normalizando banda (escala 0–10000 → 0–1).
#    → Banda min=0.000, max=9344.000
#    ✓ Normalizando banda (escala 0–10000 → 0–1).
#    → Banda min=0.000, max=8408.000
#    ✓ Normalizando banda (escala 0–10000 → 0–1).
#    → Banda min=0.000, max=8648.000
#    ✓ Normalizando banda (escala 0–10000 → 0–1).
# Cuantiles NDVI dinámicos:
#  Q1 = -0.197, Q2 = -0.037, Q3 = 0.000
# ✓ Vegetación procesada.
#
# Procesando: Topología (SRTM)
# ✓ Topografía procesada.
#
# === PREPROCESAMIENTO COMPLETO ===
# Datos guardados en: ../data/processed

# %%
# === Función para guardar figuras ===
def save_plot(fig, filename):
    out_path = os.path.join(RASTER_DIR, filename)
    fig.savefig(out_path, dpi=200, bbox_inches="tight")
    plt.close(fig)
    print(f"✓ Guardado: {out_path}")

# === Función para obtener extent geográfico ===
def get_extent(src):
    """Retorna extent [left, right, bottom, top] para usar en imshow."""
    bounds = src.bounds
    return [bounds.left, bounds.right, bounds.bottom, bounds.top]

# === Función para obtener etiquetas de ejes según CRS ===
def get_axis_labels(crs):
    """Retorna etiquetas apropiadas según si el CRS es proyectado o geográfico."""
    if crs and crs.is_projected:
        return "Coordenada Este (m)", "Coordenada Norte (m)"
    return "Longitud (°)", "Latitud (°)"

# ============================================================
# ---------------------- VEGETACIÓN S2 ------------------------
# ============================================================

veg_path = os.path.join(PREPROCESING_DIR, "vegetacion_processed.tif")

if os.path.exists(veg_path):
    
    with rasterio.open(veg_path) as src:
        red, green, blue, nir, ndvi, ndvi_class = src.read()
        extent_veg = get_extent(src)
        crs_veg = src.crs
        xlabel_veg, ylabel_veg = get_axis_labels(crs_veg)

    # ---------------------- RGB ----------------------
    rgb = np.stack([red, green, blue], axis=-1)
    rgb = np.clip(rgb, 0, 1)

    fig, ax = plt.subplots(figsize=(10, 8))
    ax.imshow(rgb, extent=extent_veg, origin='upper')
    ax.set_title(f"Composición RGB (normalizada) – Sentinel-2\nCRS: {crs_veg}", fontsize=12, fontweight='bold')
    ax.set_xlabel(xlabel_veg, fontsize=10)
    ax.set_ylabel(ylabel_veg, fontsize=10)
    ax.tick_params(axis='both', which='major', labelsize=9)
    save_plot(fig, "vegetacion_rgb.png")

    # ---------------------- NDVI MAP ----------------------
    fig, ax = plt.subplots(figsize=(10, 8))
    im = ax.imshow(ndvi, cmap="RdYlGn", vmin=-1, vmax=1, extent=extent_veg, origin='upper')
    ax.set_title(f"Índice de Vegetación (NDVI) – Sentinel-2\nCRS: {crs_veg}", fontsize=12, fontweight='bold')
    ax.set_xlabel(xlabel_veg, fontsize=10)
    ax.set_ylabel(ylabel_veg, fontsize=10)
    cbar = plt.colorbar(im, ax=ax, shrink=0.8)
    cbar.set_label("NDVI (-1: Sin vegetación, +1: Vegetación densa)", fontsize=10)
    ax.tick_params(axis='both', which='major', labelsize=9)
    save_plot(fig, "vegetacion_ndvi_map.png")

    # ---------------------- NDVI HISTOGRAM ----------------------
    fig, ax = plt.subplots(figsize=(10, 6))
    ax.hist(ndvi.ravel(), bins=50, color="green", alpha=0.7, edgecolor='darkgreen')
    ax.set_title("Distribución de valores NDVI – Sentinel-2", fontsize=12, fontweight='bold')
    ax.set_xlabel("NDVI (Índice de Vegetación)", fontsize=10)
    ax.set_ylabel("Frecuencia (cantidad de píxeles)", fontsize=10)
    ax.axvline(x=0, color='red', linestyle='--', alpha=0.7, label='NDVI = 0 (límite vegetación)')
    ax.legend(fontsize=9)
    ax.grid(axis='y', linestyle='--', alpha=0.5)
    save_plot(fig, "vegetacion_ndvi_hist.png")

    # ---------------------- NDVI CLASIFICADO ----------------------
    from matplotlib.colors import ListedColormap, BoundaryNorm
    from matplotlib.patches import Patch
    
    # Colores para las clases
    colors_ndvi = ['#bfbfbf', '#ffff66', '#66ff66', '#009900']  # Gris, Amarillo, Verde claro, Verde oscuro
    cmap_ndvi = ListedColormap(colors_ndvi)
    bounds_ndvi = [0.5, 1.5, 2.5, 3.5, 4.5]
    norm_ndvi = BoundaryNorm(bounds_ndvi, cmap_ndvi.N)

    fig, ax = plt.subplots(figsize=(10, 8))
    im = ax.imshow(ndvi_class, cmap=cmap_ndvi, norm=norm_ndvi, extent=extent_veg, origin='upper')
    ax.set_title(f"Clasificación de Cobertura Vegetal (NDVI) – Sentinel-2\nCRS: {crs_veg}", fontsize=12, fontweight='bold')
    ax.set_xlabel(xlabel_veg, fontsize=10)
    ax.set_ylabel(ylabel_veg, fontsize=10)
    ax.tick_params(axis='both', which='major', labelsize=9)
    
    # Leyenda personalizada
    legend_elements = [
        Patch(facecolor='#bfbfbf', edgecolor='black', label='1: Suelo/Agua (NDVI muy bajo)'),
        Patch(facecolor='#ffff66', edgecolor='black', label='2: Vegetación escasa (NDVI bajo)'),
        Patch(facecolor='#66ff66', edgecolor='black', label='3: Vegetación moderada (NDVI medio)'),
        Patch(facecolor='#009900', edgecolor='black', label='4: Vegetación densa (NDVI alto)')
    ]
    ax.legend(handles=legend_elements, loc='upper left', fontsize=9, title='Clases NDVI')
    save_plot(fig, "vegetacion_ndvi_class.png")

else:
    print("⚠ No se encontró vegetacion_processed.tif — saltando plots de vegetación.")


# ============================================================
# ---------------------- VIENTO ERA5 --------------------------
# ============================================================

viento_path = os.path.join(PREPROCESING_DIR, "viento_processed.tif")

if os.path.exists(viento_path):

    with rasterio.open(viento_path) as src:
        u, v, mag, direc = src.read()
        extent_viento = get_extent(src)
        crs_viento = src.crs
        xlabel_viento, ylabel_viento = get_axis_labels(crs_viento)

    # ---------------- Magnitud del viento ----------------
    fig, ax = plt.subplots(figsize=(10, 8))
    im = ax.imshow(mag, cmap="viridis", extent=extent_viento, origin='upper')
    ax.set_title(f"Magnitud del Viento – ERA5\nCRS: {crs_viento}", fontsize=12, fontweight='bold')
    ax.set_xlabel(xlabel_viento, fontsize=10)
    ax.set_ylabel(ylabel_viento, fontsize=10)
    cbar = plt.colorbar(im, ax=ax, shrink=0.8)
    cbar.set_label("Velocidad del viento (m/s)", fontsize=10)
    ax.tick_params(axis='both', which='major', labelsize=9)
    save_plot(fig, "viento_magnitud.png")

    # ---------------- Dirección del viento ----------------
    fig, ax = plt.subplots(figsize=(10, 8))
    im = ax.imshow(direc, cmap="twilight", extent=extent_viento, origin='upper')
    ax.set_title(f"Dirección del Viento – ERA5\nCRS: {crs_viento}", fontsize=12, fontweight='bold')
    ax.set_xlabel(xlabel_viento, fontsize=10)
    ax.set_ylabel(ylabel_viento, fontsize=10)
    cbar = plt.colorbar(im, ax=ax, shrink=0.8)
    cbar.set_label("Dirección (grados desde el Este, sentido antihorario)", fontsize=10)
    ax.tick_params(axis='both', which='major', labelsize=9)
    save_plot(fig, "viento_direccion.png")

else:
    print("⚠ No se encontró viento_processed.tif — saltando plots de viento.")


# ============================================================
# ---------------------- TOPOGRAFÍA SRTM ---------------------
# ============================================================

topo_path = os.path.join(PREPROCESING_DIR, "topologia_processed.tif")

if os.path.exists(topo_path):

    with rasterio.open(topo_path) as src:
        elev, slope, aspect = src.read()
        extent_topo = get_extent(src)
        crs_topo = src.crs
        xlabel_topo, ylabel_topo = get_axis_labels(crs_topo)

    # ---------------- Elevación ----------------
    fig, ax = plt.subplots(figsize=(10, 8))
    im = ax.imshow(elev, cmap="terrain", extent=extent_topo, origin='upper')
    ax.set_title(f"Modelo Digital de Elevación – SRTM\nCRS: {crs_topo}", fontsize=12, fontweight='bold')
    ax.set_xlabel(xlabel_topo, fontsize=10)
    ax.set_ylabel(ylabel_topo, fontsize=10)
    cbar = plt.colorbar(im, ax=ax, shrink=0.8)
    cbar.set_label("Elevación (m.s.n.m.)", fontsize=10)
    ax.tick_params(axis='both', which='major', labelsize=9)
    save_plot(fig, "topografia_elevacion.png")

    # ---------------- Pendiente ----------------
    fig, ax = plt.subplots(figsize=(10, 8))
    im = ax.imshow(slope, cmap="magma", extent=extent_topo, origin='upper')
    ax.set_title(f"Pendiente del Terreno – SRTM\nCRS: {crs_topo}", fontsize=12, fontweight='bold')
    ax.set_xlabel(xlabel_topo, fontsize=10)
    ax.set_ylabel(ylabel_topo, fontsize=10)
    cbar = plt.colorbar(im, ax=ax, shrink=0.8)
    cbar.set_label("Pendiente (grados)", fontsize=10)
    ax.tick_params(axis='both', which='major', labelsize=9)
    save_plot(fig, "topografia_pendiente.png")

    # ---------------- Aspecto ----------------
    fig, ax = plt.subplots(figsize=(10, 8))
    im = ax.imshow(aspect, cmap="twilight", extent=extent_topo, origin='upper')
    ax.set_title(f"Orientación de la Pendiente (Aspect) – SRTM\nCRS: {crs_topo}", fontsize=12, fontweight='bold')
    ax.set_xlabel(xlabel_topo, fontsize=10)
    ax.set_ylabel(ylabel_topo, fontsize=10)
    cbar = plt.colorbar(im, ax=ax, shrink=0.8)
    cbar.set_label("Orientación (grados, 0°=Norte, 90°=Este, 180°=Sur, 270°=Oeste)", fontsize=10)
    ax.tick_params(axis='both', which='major', labelsize=9)
    save_plot(fig, "topografia_orientacion.png")

else:
    print("⚠ No se encontró topologia_processed.tif — saltando plots de topografía.")


print("\n=== FIGURAS GENERADAS Y GUARDADAS EN:", RASTER_DIR, "===")
# Out:
# ✓ Guardado: ../outputs/figures/raster/processed\vegetacion_rgb.png
# ✓ Guardado: ../outputs/figures/raster/processed\vegetacion_ndvi_map.png
# ✓ Guardado: ../outputs/figures/raster/processed\vegetacion_ndvi_hist.png
# ✓ Guardado: ../outputs/figures/raster/processed\vegetacion_ndvi_class.png
# ✓ Guardado: ../outputs/figures/raster/processed\viento_magnitud.png
# ✓ Guardado: ../outputs/figures/raster/processed\viento_direccion.png
# ✓ Guardado: ../outputs/figures/raster/processed\topografia_elevacion.png
# ✓ Guardado: ../outputs/figures/raster/processed\topografia_pendiente.png
# ✓ Guardado: ../outputs/figures/raster/processed\topografia_orientacion.png
#
# === FIGURAS GENERADAS Y GUARDADAS EN: ../outputs/figures/raster/processed ===
